# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        eket   4.6412    7.9209     23.43        93         100
# 1        1      mirnyy  62.5353  113.9611     25.98        33          34
# 2        2  bredasdorp -34.5322   20.0403      9.71        85          96
# 3        3   ventspils  57.3894   21.5606     17.96        88           0
# 4        4       lepsy  46.2350   78.9456     25.93        39          88
#
#    Wind Speed Country        Date
# 0        1.06      NG  1688879843
# 1        0.51      RU  1688879843
# 2        4.70      ZA  1688879844
# 3        3.60      LV  1688879844
# 4        1.56      KZ  1688879845

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity")

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %%
# Narrow down cities that fit criteria and drop any results with null values
criteria = city_data_df.loc[(city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 20) & \
                            (city_data_df["Wind Speed"] < 4.5) & (city_data_df["Cloudiness"] == 0) & \
                            (city_data_df["Humidity"] < 75)]

# Drop any rows with null values
criteria_clean = criteria.dropna(how="any")

# Display sample data
criteria_clean.head()
# Out:
#      City_ID            City      Lat      Lng  Max Temp  Humidity  \
# 68        68          madaba  31.5833  35.6667     23.09        65
# 157      157         colonia  50.9333   6.9500     24.42        71
# 298      298       ain sefra  32.7500  -0.5833     25.69        20
# 304      304          illizi  26.4833   8.4667     25.89        20
# 346      346  capo d'orlando  38.1435  14.7305     26.34        56
#
#      Cloudiness  Wind Speed Country        Date
# 68            0        2.65      JO  1688879886
# 157           0        1.03      DE  1688879754
# 298           0        1.81      DZ  1688880035
# 304           0        4.27      DZ  1688880038
# 346           0        0.54      IT  1688880065

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = criteria_clean.copy().drop(columns=["City_ID", "Max Temp", "Cloudiness", "Wind Speed", "Date"])
hotel_df = hotel_df[["City", "Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 68           madaba      JO  31.5833   35.6667        65
# 157         colonia      DE  50.9333    6.9500        71
# 298       ain sefra      DZ  32.7500   -0.5833        20
# 304          illizi      DZ  26.4833    8.4667        20
# 346  capo d'orlando      IT  38.1435   14.7305        56
# 349        filiatra      GR  37.1500   21.5833        70
# 363       geraldton      AU -28.7667  114.6000        52
# 379         ballina      AU -28.8667  153.5667        38
# 515  khamis mushait      SA  18.3064   42.7292        36
# 537         makarov      RU  48.6333  142.8000        55
# 549      blackwater      AU -23.5833  148.8833        21

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 10
params = {
    "apiKey": geoapify_key,
    "limit": limit,
    "categories": f"accommodation.hotel"}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = hotel_df.loc[index, "Lat"]
    lon = hotel_df.loc[index, "Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# madaba - nearest hotel: Ma'in Hot Spring Resort & Spa
# colonia - nearest hotel: Wasserturm Hotel Cologne
# ain sefra - nearest hotel: فندق مكثر
# illizi - nearest hotel: بوناقة
# capo d'orlando - nearest hotel: Hotel Sant'Andrea
# filiatra - nearest hotel: Hotel Limenari
# geraldton - nearest hotel: Ocean Centre Hotel
# ballina - nearest hotel: Ballina Beach Resort
# khamis mushait - nearest hotel: No hotel found
# makarov - nearest hotel: No hotel found
# blackwater - nearest hotel: No hotel found
#                City Country      Lat       Lng  Humidity  \
# 68           madaba      JO  31.5833   35.6667        65
# 157         colonia      DE  50.9333    6.9500        71
# 298       ain sefra      DZ  32.7500   -0.5833        20
# 304          illizi      DZ  26.4833    8.4667        20
# 346  capo d'orlando      IT  38.1435   14.7305        56
# 349        filiatra      GR  37.1500   21.5833        70
# 363       geraldton      AU -28.7667  114.6000        52
# 379         ballina      AU -28.8667  153.5667        38
# 515  khamis mushait      SA  18.3064   42.7292        36
# 537         makarov      RU  48.6333  142.8000        55
# 549      blackwater      AU -23.5833  148.8833        21
#
#                         Hotel Name
# 68   Ma'in Hot Spring Resort & Spa
# 157       Wasserturm Hotel Cologne
# 298                      فندق مكثر
# 304                         بوناقة
# 346              Hotel Sant'Andrea
# 349                 Hotel Limenari
# 363             Ocean Centre Hotel
# 379           Ballina Beach Resort
# 515                 No hotel found
# 537                 No hotel found
# 549                 No hotel found

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "Country",
    hover_cols = ["Hotel Name", "Country"])

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Country,Humidity,Hotel Name)
