# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units=metric&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
#         # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#     If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | kristiansund
# Processing Record 5 of Set 1 | bikenibeu village
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | adamstown
# Processing Record 10 of Set 1 | hawaiian paradise park
# Processing Record 11 of Set 1 | akureyri
# Processing Record 12 of Set 1 | stepnogorsk
# Processing Record 13 of Set 1 | callao
# Processing Record 14 of Set 1 | am djarass
# City not found. Skipping...
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | college
# Processing Record 17 of Set 1 | yazoo city
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | tucurui
# Processing Record 20 of Set 1 | crane
# Processing Record 21 of Set 1 | flowood
# Processing Record 22 of Set 1 | hammerfest
# Processing Record 23 of Set 1 | badger
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | olonkinbyen
# Processing Record 27 of Set 1 | morden
# Processing Record 28 of Set 1 | geraldton
# Processing Record 29 of Set 1 | puerto natales
# Processing Record 30 of Set 1 | covington
# Processing Record 31 of Set 1 | nongpoh
# Processing Record 32 of Set 1 | lavrio
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | enewetak
# Processing Record 35 of Set 1 | fort bragg
# Processing Record 36 of Set 1 | mogadishu
# Processing Record 37 of Set 1 | sangmelima
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | franklin
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | kralendijk
# Processing Record 42 of Set 1 | san antonio oeste
# Processing Record 43 of Set 1 | pisco
# Processing Record 44 of Set 1 | arno
# Processing Record 45 of Set 1 | blackmans bay
# Processing Record 46 of Set 1 | tual
# Processing Record 47 of Set 1 | usinsk
# Processing Record 48 of Set 1 | ola
# Processing Record 49 of Set 1 | drezna
# Processing Record 50 of Set 1 | hilo
# Processing Record 0 of Set 2 | walvis bay
# Processing Record 1 of Set 2 | taghazout
# Processing Record 2 of Set 2 | wailua homesteads
# Processing Record 3 of Set 2 | fort st. john
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | aasiaat
# Processing Record 6 of Set 2 | mezhdurechenskiy
# Processing Record 7 of Set 2 | vilyuchinsk
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | ghadamis
# Processing Record 10 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | coihueco
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 17 of Set 2 | devils lake
# Processing Record 18 of Set 2 | rundu
# Processing Record 19 of Set 2 | isafjordur
# Processing Record 20 of Set 2 | buctzotz
# Processing Record 21 of Set 2 | vaxjo
# Processing Record 22 of Set 2 | bethanie
# Processing Record 23 of Set 2 | port lincoln
# Processing Record 24 of Set 2 | greymouth
# Processing Record 25 of Set 2 | el bauga
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | nuku'alofa
# Processing Record 28 of Set 2 | mohr
# Processing Record 29 of Set 2 | leticia
# Processing Record 30 of Set 2 | palmares do sul
# Processing Record 31 of Set 2 | vila nova de foz coa
# Processing Record 32 of Set 2 | luderitz
# Processing Record 33 of Set 2 | kununurra
# Processing Record 34 of Set 2 | krylovskaya
# Processing Record 35 of Set 2 | tozeur
# Processing Record 36 of Set 2 | inhambane
# Processing Record 37 of Set 2 | opuwo
# Processing Record 38 of Set 2 | dudinka
# Processing Record 39 of Set 2 | labytnangi
# Processing Record 40 of Set 2 | puerto lempira
# Processing Record 41 of Set 2 | oodweyne
# Processing Record 42 of Set 2 | barra
# Processing Record 43 of Set 2 | al kharj
# Processing Record 44 of Set 2 | margaret river
# Processing Record 45 of Set 2 | peterhead
# Processing Record 46 of Set 2 | weno
# Processing Record 47 of Set 2 | hinton
# Processing Record 48 of Set 2 | zin'kiv
# Processing Record 49 of Set 2 | pertek
# Processing Record 0 of Set 3 | joshimath
# Processing Record 1 of Set 3 | lumphat
# Processing Record 2 of Set 3 | kultali
# City not found. Skipping...
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | champerico
# Processing Record 5 of Set 3 | uturoa
# Processing Record 6 of Set 3 | forster
# Processing Record 7 of Set 3 | narasapur
# Processing Record 8 of Set 3 | sungai penuh
# Processing Record 9 of Set 3 | ghat
# Processing Record 10 of Set 3 | taro
# Processing Record 11 of Set 3 | puerto la cruz
# Processing Record 12 of Set 3 | sinop
# Processing Record 13 of Set 3 | carleton place
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | ust-nera
# Processing Record 17 of Set 3 | pionerskiy
# Processing Record 18 of Set 3 | sisimiut
# Processing Record 19 of Set 3 | ilhabela
# Processing Record 20 of Set 3 | salinopolis
# Processing Record 21 of Set 3 | port hedland
# Processing Record 22 of Set 3 | vadso
# Processing Record 23 of Set 3 | salalah
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | khark
# Processing Record 27 of Set 3 | susuman
# Processing Record 28 of Set 3 | zangguy
# City not found. Skipping...
# Processing Record 29 of Set 3 | utrik
# Processing Record 30 of Set 3 | tyukhtet
# Processing Record 31 of Set 3 | namibe
# Processing Record 32 of Set 3 | kostomuksha
# Processing Record 33 of Set 3 | nagqu
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | nemuro
# Processing Record 36 of Set 3 | aykhal
# Processing Record 37 of Set 3 | apolinario saravia
# Processing Record 38 of Set 3 | rumoi
# Processing Record 39 of Set 3 | saipan
# Processing Record 40 of Set 3 | yendi
# Processing Record 41 of Set 3 | beihai
# Processing Record 42 of Set 3 | edinburgh of the seven seas
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | la passe
# Processing Record 45 of Set 3 | barra de santo antonio
# Processing Record 46 of Set 3 | odienne
# Processing Record 47 of Set 3 | invercargill
# Processing Record 48 of Set 3 | fale old settlement
# Processing Record 49 of Set 3 | vila franca do campo
# Processing Record 0 of Set 4 | tolanaro
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | howard springs
# Processing Record 3 of Set 4 | lihue
# Processing Record 4 of Set 4 | tougan
# Processing Record 5 of Set 4 | hamilton
# Processing Record 6 of Set 4 | kingston
# Processing Record 7 of Set 4 | bamboo flat
# Processing Record 8 of Set 4 | nema
# Processing Record 9 of Set 4 | port saint john's
# Processing Record 10 of Set 4 | inarajan village
# Processing Record 11 of Set 4 | glace bay
# Processing Record 12 of Set 4 | udachny
# Processing Record 13 of Set 4 | vorgashor
# Processing Record 14 of Set 4 | harlan
# Processing Record 15 of Set 4 | punta arenas
# Processing Record 16 of Set 4 | chibougamau
# Processing Record 17 of Set 4 | esperanza
# Processing Record 18 of Set 4 | noumea
# Processing Record 19 of Set 4 | manismata
# Processing Record 20 of Set 4 | port mathurin
# Processing Record 21 of Set 4 | al wafrah
# Processing Record 22 of Set 4 | sao paulo de olivenca
# Processing Record 23 of Set 4 | tubarjal
# Processing Record 24 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 25 of Set 4 | arraial do cabo
# Processing Record 26 of Set 4 | renk
# City not found. Skipping...
# Processing Record 27 of Set 4 | itoman
# Processing Record 28 of Set 4 | enriquillo
# Processing Record 29 of Set 4 | puerto deseado
# Processing Record 30 of Set 4 | constantia
# Processing Record 31 of Set 4 | hovd
# Processing Record 32 of Set 4 | talnakh
# Processing Record 33 of Set 4 | kpandae
# Processing Record 34 of Set 4 | motueka
# Processing Record 35 of Set 4 | qaqortoq
# Processing Record 36 of Set 4 | la'ie
# Processing Record 37 of Set 4 | salavan
# Processing Record 38 of Set 4 | mount pearl
# Processing Record 39 of Set 4 | eirunepe
# Processing Record 40 of Set 4 | general acha
# Processing Record 41 of Set 4 | stanley
# Processing Record 42 of Set 4 | mahabe
# City not found. Skipping...
# Processing Record 43 of Set 4 | weining
# Processing Record 44 of Set 4 | coquimbo
# Processing Record 45 of Set 4 | n'zeto
# Processing Record 46 of Set 4 | suva
# Processing Record 47 of Set 4 | makokou
# Processing Record 48 of Set 4 | cabedelo
# Processing Record 49 of Set 4 | dryden
# Processing Record 0 of Set 5 | west island
# Processing Record 1 of Set 5 | kolonia
# Processing Record 2 of Set 5 | rio bueno
# Processing Record 3 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 4 of Set 5 | san antonio de pale
# Processing Record 5 of Set 5 | broome
# Processing Record 6 of Set 5 | mek'ele
# Processing Record 7 of Set 5 | east london
# Processing Record 8 of Set 5 | neiafu
# Processing Record 9 of Set 5 | burkburnett
# Processing Record 10 of Set 5 | khomeyni shahr
# Processing Record 11 of Set 5 | bayan nur
# City not found. Skipping...
# Processing Record 12 of Set 5 | banda aceh
# Processing Record 13 of Set 5 | reyes
# Processing Record 14 of Set 5 | mount isa
# Processing Record 15 of Set 5 | hermanus
# Processing Record 16 of Set 5 | alice springs
# Processing Record 17 of Set 5 | carnarvon
# Processing Record 18 of Set 5 | bilibino
# Processing Record 19 of Set 5 | sarangani
# Processing Record 20 of Set 5 | port-cartier
# Processing Record 21 of Set 5 | malango
# Processing Record 22 of Set 5 | ulladulla
# Processing Record 23 of Set 5 | estreito
# Processing Record 24 of Set 5 | waingapu
# Processing Record 25 of Set 5 | lazaro cardenas
# Processing Record 26 of Set 5 | bandraboua
# Processing Record 27 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 5 | iskateley
# Processing Record 29 of Set 5 | mersa matruh
# Processing Record 30 of Set 5 | pathein
# Processing Record 31 of Set 5 | vila velha
# Processing Record 32 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 33 of Set 5 | sola
# Processing Record 34 of Set 5 | mirriah
# Processing Record 35 of Set 5 | zhanaozen
# Processing Record 36 of Set 5 | kailua-kona
# Processing Record 37 of Set 5 | smithers
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | coahuayana de hidalgo
# Processing Record 40 of Set 5 | zimmerman
# Processing Record 41 of Set 5 | eyl
# Processing Record 42 of Set 5 | nova vicosa
# Processing Record 43 of Set 5 | richards bay
# Processing Record 44 of Set 5 | mawu
# Processing Record 45 of Set 5 | atherton
# Processing Record 46 of Set 5 | uyuni
# Processing Record 47 of Set 5 | gillette
# Processing Record 48 of Set 5 | bardai
# Processing Record 49 of Set 5 | douentza
# Processing Record 0 of Set 6 | suicheng
# Processing Record 1 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 6 | bereznik
# Processing Record 3 of Set 6 | thohoyandou
# Processing Record 4 of Set 6 | gadzhiyevo
# Processing Record 5 of Set 6 | klaksvik
# Processing Record 6 of Set 6 | ust-tsilma
# Processing Record 7 of Set 6 | dalnegorsk
# Processing Record 8 of Set 6 | shuangyang
# Processing Record 9 of Set 6 | saint-georges
# Processing Record 10 of Set 6 | qamdo
# Processing Record 11 of Set 6 | kapenguria
# Processing Record 12 of Set 6 | kapa'a
# Processing Record 13 of Set 6 | vandalia
# Processing Record 14 of Set 6 | villa gesell
# Processing Record 15 of Set 6 | kone
# Processing Record 16 of Set 6 | papatowai
# Processing Record 17 of Set 6 | tondano
# Processing Record 18 of Set 6 | ahmadpur east
# Processing Record 19 of Set 6 | kalmunai
# Processing Record 20 of Set 6 | tomatlan
# Processing Record 21 of Set 6 | toshloq
# Processing Record 22 of Set 6 | pantai cenang
# City not found. Skipping...
# Processing Record 23 of Set 6 | papao
# Processing Record 24 of Set 6 | nalut
# Processing Record 25 of Set 6 | st. john's
# Processing Record 26 of Set 6 | ak-dovurak
# Processing Record 27 of Set 6 | sparti
# Processing Record 28 of Set 6 | samana
# Processing Record 29 of Set 6 | satuba
# Processing Record 30 of Set 6 | todos santos
# Processing Record 31 of Set 6 | huarmey
# Processing Record 32 of Set 6 | aban
# Processing Record 33 of Set 6 | lerwick
# Processing Record 34 of Set 6 | port augusta
# Processing Record 35 of Set 6 | whitehorse
# Processing Record 36 of Set 6 | atafu village
# Processing Record 37 of Set 6 | codrington
# Processing Record 38 of Set 6 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 39 of Set 6 | arenapolis
# Processing Record 40 of Set 6 | rikaze
# Processing Record 41 of Set 6 | cooper's town
# Processing Record 42 of Set 6 | happy valley-goose bay
# Processing Record 43 of Set 6 | rabaul
# Processing Record 44 of Set 6 | polyarnyy
# Processing Record 45 of Set 6 | douglas
# Processing Record 46 of Set 6 | tanout
# Processing Record 47 of Set 6 | tazovsky
# Processing Record 48 of Set 6 | tofol
# Processing Record 49 of Set 6 | taoudenni
# Processing Record 0 of Set 7 | tsengel
# Processing Record 1 of Set 7 | selfoss
# Processing Record 2 of Set 7 | saint-philippe
# Processing Record 3 of Set 7 | cabo san lucas
# Processing Record 4 of Set 7 | bloomsburg
# Processing Record 5 of Set 7 | serdar
# Processing Record 6 of Set 7 | san luis de la loma
# Processing Record 7 of Set 7 | christies beach
# Processing Record 8 of Set 7 | sterling
# Processing Record 9 of Set 7 | beau vallon
# Processing Record 10 of Set 7 | pierre
# Processing Record 11 of Set 7 | santa ana
# Processing Record 12 of Set 7 | island harbour
# Processing Record 13 of Set 7 | mahina
# Processing Record 14 of Set 7 | tambura
# Processing Record 15 of Set 7 | mangrol
# Processing Record 16 of Set 7 | arkadelphia
# Processing Record 17 of Set 7 | poronaysk
# Processing Record 18 of Set 7 | kruisfontein
# Processing Record 19 of Set 7 | nueva palestina
# Processing Record 20 of Set 7 | nikolayevsk-on-amure
# Processing Record 21 of Set 7 | cudillero
# Processing Record 22 of Set 7 | ulaangom
# Processing Record 23 of Set 7 | corner brook
# Processing Record 24 of Set 7 | mejit
# Processing Record 25 of Set 7 | la mojonera
# Processing Record 26 of Set 7 | shchyolkino
# Processing Record 27 of Set 7 | santiago de cao
# Processing Record 28 of Set 7 | afaahiti
# Processing Record 29 of Set 7 | anxiang
# Processing Record 30 of Set 7 | kilkeel
# Processing Record 31 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 32 of Set 7 | santa terezinha
# Processing Record 33 of Set 7 | rawson
# Processing Record 34 of Set 7 | kenai
# Processing Record 35 of Set 7 | kadiri
# Processing Record 36 of Set 7 | calama
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | tari
# Processing Record 39 of Set 7 | anadyr
# Processing Record 40 of Set 7 | holyhead
# Processing Record 41 of Set 7 | fortuna
# Processing Record 42 of Set 7 | nova sintra
# Processing Record 43 of Set 7 | tutoia
# Processing Record 44 of Set 7 | mugia
# Processing Record 45 of Set 7 | escanaba
# Processing Record 46 of Set 7 | ati
# Processing Record 47 of Set 7 | ancud
# Processing Record 48 of Set 7 | maulavi bazar
# Processing Record 49 of Set 7 | aquidauana
# Processing Record 0 of Set 8 | prado
# Processing Record 1 of Set 8 | duartina
# Processing Record 2 of Set 8 | rexburg
# Processing Record 3 of Set 8 | tsiombe
# Processing Record 4 of Set 8 | caleta de carquin
# Processing Record 5 of Set 8 | trincomalee
# Processing Record 6 of Set 8 | bouarfa
# Processing Record 7 of Set 8 | san andres
# Processing Record 8 of Set 8 | mokhsogollokh
# Processing Record 9 of Set 8 | filadelfia
# Processing Record 10 of Set 8 | iglino
# Processing Record 11 of Set 8 | kaa-khem
# Processing Record 12 of Set 8 | dongcun
# Processing Record 13 of Set 8 | axim
# Processing Record 14 of Set 8 | chita
# Processing Record 15 of Set 8 | cannonvale
# Processing Record 16 of Set 8 | uaboe
# City not found. Skipping...
# Processing Record 17 of Set 8 | nar'yan-mar
# Processing Record 18 of Set 8 | dawei
# Processing Record 19 of Set 8 | langepas
# Processing Record 20 of Set 8 | linevo
# Processing Record 21 of Set 8 | harsin
# Processing Record 22 of Set 8 | sokone
# Processing Record 23 of Set 8 | novokazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 8 | thunder bay
# Processing Record 25 of Set 8 | port pirie
# Processing Record 26 of Set 8 | hafar al-batin
# Processing Record 27 of Set 8 | colchani
# Processing Record 28 of Set 8 | puerto baquerizo moreno
# Processing Record 29 of Set 8 | balykshi
# Processing Record 30 of Set 8 | inderbor
# Processing Record 31 of Set 8 | lincoln
# Processing Record 32 of Set 8 | brookings
# Processing Record 33 of Set 8 | kosti
# Processing Record 34 of Set 8 | sitka
# Processing Record 35 of Set 8 | abeche
# Processing Record 36 of Set 8 | noosa heads
# Processing Record 37 of Set 8 | magadan
# Processing Record 38 of Set 8 | lensk
# Processing Record 39 of Set 8 | kurumkan
# Processing Record 40 of Set 8 | phillip island
# Processing Record 41 of Set 8 | wesselsbron
# Processing Record 42 of Set 8 | pitimbu
# Processing Record 43 of Set 8 | al kharijah
# Processing Record 44 of Set 8 | keflavik
# Processing Record 45 of Set 8 | churachandpur
# Processing Record 46 of Set 8 | berezovyy
# Processing Record 47 of Set 8 | kelibia
# Processing Record 48 of Set 8 | tarauaca
# Processing Record 49 of Set 8 | minas de marcona
# Processing Record 0 of Set 9 | mil'kovo
# Processing Record 1 of Set 9 | alofi
# Processing Record 2 of Set 9 | nadym
# Processing Record 3 of Set 9 | siracusa
# Processing Record 4 of Set 9 | myitkyina
# Processing Record 5 of Set 9 | sosnogorsk
# Processing Record 6 of Set 9 | al bardiyah
# Processing Record 7 of Set 9 | ban houayxay
# Processing Record 8 of Set 9 | amursk
# Processing Record 9 of Set 9 | saint-benoit
# Processing Record 10 of Set 9 | necochea
# Processing Record 11 of Set 9 | manaure
# Processing Record 12 of Set 9 | kerikeri
# Processing Record 13 of Set 9 | dali
# Processing Record 14 of Set 9 | acapulco de juarez
# Processing Record 15 of Set 9 | kropyvnytskyi
# Processing Record 16 of Set 9 | zavetnoye
# Processing Record 17 of Set 9 | klyuchi
# Processing Record 18 of Set 9 | san ignacio
# Processing Record 19 of Set 9 | agua branca
# Processing Record 20 of Set 9 | tazacorte
# Processing Record 21 of Set 9 | la asuncion
# Processing Record 22 of Set 9 | qusmuryn
# Processing Record 23 of Set 9 | mandiana
# Processing Record 24 of Set 9 | funafuti
# Processing Record 25 of Set 9 | vernon
# Processing Record 26 of Set 9 | houghton
# Processing Record 27 of Set 9 | miches
# Processing Record 28 of Set 9 | puerto cabezas
# Processing Record 29 of Set 9 | taltal
# Processing Record 30 of Set 9 | northam
# Processing Record 31 of Set 9 | sao jose da coroa grande
# Processing Record 32 of Set 9 | benguela
# Processing Record 33 of Set 9 | chui
# Processing Record 34 of Set 9 | viedma
# Processing Record 35 of Set 9 | toga village
# City not found. Skipping...
# Processing Record 36 of Set 9 | yangor
# City not found. Skipping...
# Processing Record 37 of Set 9 | priargunsk
# Processing Record 38 of Set 9 | igrim
# Processing Record 39 of Set 9 | doka
# Processing Record 40 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 41 of Set 9 | telhara
# Processing Record 42 of Set 9 | camiri
# Processing Record 43 of Set 9 | corund
# Processing Record 44 of Set 9 | kirovsk
# Processing Record 45 of Set 9 | goundi
# Processing Record 46 of Set 9 | rongelap
# Processing Record 47 of Set 9 | porto santo stefano
# Processing Record 48 of Set 9 | nelson bay
# Processing Record 49 of Set 9 | novodvinsk
# Processing Record 0 of Set 10 | sirte
# Processing Record 1 of Set 10 | porto novo
# Processing Record 2 of Set 10 | desaguadero
# Processing Record 3 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 4 of Set 10 | kirensk
# Processing Record 5 of Set 10 | campo gallo
# Processing Record 6 of Set 10 | howrah
# Processing Record 7 of Set 10 | lagoa
# Processing Record 8 of Set 10 | moyynkum
# Processing Record 9 of Set 10 | zarghun shahr
# Processing Record 10 of Set 10 | khovd
# Processing Record 11 of Set 10 | haiku-pauwela
# Processing Record 12 of Set 10 | kirakira
# Processing Record 13 of Set 10 | taco pozo
# Processing Record 14 of Set 10 | holualoa
# Processing Record 15 of Set 10 | sao vicente
# Processing Record 16 of Set 10 | flying fish cove
# Processing Record 17 of Set 10 | banyo
# Processing Record 18 of Set 10 | prince rupert
# Processing Record 19 of Set 10 | springbok
# Processing Record 20 of Set 10 | castillos
# Processing Record 21 of Set 10 | bela
# Processing Record 22 of Set 10 | kavaratti
# Processing Record 23 of Set 10 | chonchi
# Processing Record 24 of Set 10 | conduaga
# Processing Record 25 of Set 10 | belyy yar
# Processing Record 26 of Set 10 | kroya
# Processing Record 27 of Set 10 | ambovombe
# Processing Record 28 of Set 10 | kumagunnam
# Processing Record 29 of Set 10 | esquel
# Processing Record 30 of Set 10 | barcelos
# Processing Record 31 of Set 10 | mariinsk
# Processing Record 32 of Set 10 | kiunga
# Processing Record 33 of Set 10 | egilsstadir
# Processing Record 34 of Set 10 | severo-yeniseyskiy
# Processing Record 35 of Set 10 | lesnoy
# Processing Record 36 of Set 10 | kaitong
# Processing Record 37 of Set 10 | erdenet
# Processing Record 38 of Set 10 | remire-montjoly
# Processing Record 39 of Set 10 | rosetta
# Processing Record 40 of Set 10 | srivardhan
# Processing Record 41 of Set 10 | at taj
# Processing Record 42 of Set 10 | kuching
# Processing Record 43 of Set 10 | ko pha ngan
# Processing Record 44 of Set 10 | ixtapa
# Processing Record 45 of Set 10 | tralee
# Processing Record 46 of Set 10 | yar
# Processing Record 47 of Set 10 | peace river
# Processing Record 48 of Set 10 | yebaishou
# Processing Record 49 of Set 10 | caspe
# Processing Record 0 of Set 11 | manggar
# Processing Record 1 of Set 11 | tindouf
# Processing Record 2 of Set 11 | santa elena de uairen
# Processing Record 3 of Set 11 | murzzuschlag
# Processing Record 4 of Set 11 | nili
# Processing Record 5 of Set 11 | labuan
# Processing Record 6 of Set 11 | olds
# Processing Record 7 of Set 11 | darwin
# Processing Record 8 of Set 11 | coronel suarez
# Processing Record 9 of Set 11 | nikol'sk
# Processing Record 10 of Set 11 | lata
# Processing Record 11 of Set 11 | akrehamn
# Processing Record 12 of Set 11 | lyantor
# Processing Record 13 of Set 11 | nuriootpa
# Processing Record 14 of Set 11 | al jawf
# Processing Record 15 of Set 11 | qui nhon
# Processing Record 16 of Set 11 | banswara
# Processing Record 17 of Set 11 | vershino-darasunskiy
# Processing Record 18 of Set 11 | carinhanha
# Processing Record 19 of Set 11 | pasuquin
# Processing Record 20 of Set 11 | dawesville
# Processing Record 21 of Set 11 | sheridan
# Processing Record 22 of Set 11 | goondiwindi
# Processing Record 23 of Set 11 | yuzhno-kurilsk
# Processing Record 24 of Set 11 | seogwipo
# City not found. Skipping...
# Processing Record 25 of Set 11 | port nelson
# Processing Record 26 of Set 11 | acarau
# Processing Record 27 of Set 11 | la serena
# Processing Record 28 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 29 of Set 11 | strugi-krasnyye
# Processing Record 30 of Set 11 | usta muhammad
# Processing Record 31 of Set 11 | broken hill
# Processing Record 32 of Set 11 | turaif
# Processing Record 33 of Set 11 | saint-leu
# Processing Record 34 of Set 11 | shingu
# Processing Record 35 of Set 11 | lindi
# Processing Record 36 of Set 11 | rajanpur
# Processing Record 37 of Set 11 | votuporanga
# Processing Record 38 of Set 11 | boromo
# Processing Record 39 of Set 11 | amahai
# Processing Record 40 of Set 11 | koz'modem'yansk
# Processing Record 41 of Set 11 | hami
# Processing Record 42 of Set 11 | ban nam yuen
# Processing Record 43 of Set 11 | laguna
# Processing Record 44 of Set 11 | smidovich
# Processing Record 45 of Set 11 | nuuk
# Processing Record 46 of Set 11 | brak
# Processing Record 47 of Set 11 | horta
# Processing Record 48 of Set 11 | pundong
# Processing Record 49 of Set 11 | atar
# Processing Record 0 of Set 12 | bonthe
# Processing Record 1 of Set 12 | fiambala
# Processing Record 2 of Set 12 | lucas
# Processing Record 3 of Set 12 | kuusamo
# Processing Record 4 of Set 12 | dunda
# Processing Record 5 of Set 12 | hiratacho
# Processing Record 6 of Set 12 | tura
# Processing Record 7 of Set 12 | mandera
# Processing Record 8 of Set 12 | amga
# Processing Record 9 of Set 12 | bratsk
# Processing Record 10 of Set 12 | harper
# Processing Record 11 of Set 12 | corinto
# Processing Record 12 of Set 12 | cambria
# Processing Record 13 of Set 12 | yambio
# Processing Record 14 of Set 12 | angaur state
# Processing Record 15 of Set 12 | olyokminsk
# Processing Record 16 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 17 of Set 12 | kangding
# Processing Record 18 of Set 12 | masterton
# Processing Record 19 of Set 12 | brisas de zicatela
# Processing Record 20 of Set 12 | vohipaho
# City not found. Skipping...
# Processing Record 21 of Set 12 | christchurch
# Processing Record 22 of Set 12 | changling
# Processing Record 23 of Set 12 | leninskoye
# Processing Record 24 of Set 12 | brokopondo
# Processing Record 25 of Set 12 | rey bouba
# Processing Record 26 of Set 12 | oltinko'l
# Processing Record 27 of Set 12 | kotputli
# Processing Record 28 of Set 12 | stuttgart
# Processing Record 29 of Set 12 | sikonge
# Processing Record 30 of Set 12 | la sarre
# Processing Record 31 of Set 12 | sechura
# Processing Record 32 of Set 12 | ashland
# Processing Record 33 of Set 12 | dubbo
# Processing Record 34 of Set 12 | natal
# Processing Record 35 of Set 12 | lakatoro
# Processing Record 36 of Set 12 | saint-pierre
# Processing Record 37 of Set 12 | altai
# Processing Record 38 of Set 12 | mangalia
# Processing Record 39 of Set 12 | sanchor
# Processing Record 40 of Set 12 | punta alta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          grytviken -54.2811  -36.5092     -6.71        84          25
# 1           waitangi -43.9535 -176.5597     12.12        80          50
# 2             avarua -21.2078 -159.7750     27.03        78          75
# 3       kristiansund  63.1115    7.7320     15.03        88          75
# 4  bikenibeu village   1.3673  173.1241     27.98        89         100
#
#    Wind Speed Country        Date
# 0        5.34      GS  1688858853
# 1        1.79      NZ  1688858854
# 2        7.72      CK  1688858854
# 3        1.54      NO  1688858855
# 4        3.09      KI  1688858856

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                grytviken -54.2811  -36.5092     -6.71        84          25
# 1                 waitangi -43.9535 -176.5597     12.12        80          50
# 2                   avarua -21.2078 -159.7750     27.03        78          75
# 3             kristiansund  63.1115    7.7320     15.03        88          75
# 4        bikenibeu village   1.3673  173.1241     27.98        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.34      GS  1688858853
# 1              1.79      NZ  1688858854
# 2              7.72      CK  1688858854
# 3              1.54      NO  1688858855
# 4              3.09      KI  1688858856

# %% [markdown]
# Create the Scatter Plots Requested
# Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df["Lat"]
temperature = city_data_df["Max Temp"]
plt.scatter(latitude, temperature, edgecolors="black")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Max Latitude vs Temperature ({date})")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# Latitude vs Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude = city_data_df["Lat"]
humidity = city_data_df["Humidity"]
plt.scatter(latitude, humidity, edgecolors="black")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Max Latitude vs Humidity (2023-07-09)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# Latitude vs Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]
plt.scatter(latitude, cloudiness, edgecolors="black")

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Max Latitude vs Cloudiness (2023-07-09)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# Latitude vs Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed
latitude = city_data_df["Lat"]
wind_speed = city_data_df["Wind Speed"]
plt.scatter(latitude, wind_speed, edgecolors="black")


# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Max Latitude vs Wind Speed (2023-07-09)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Define a function to create Linear Regression plots
def regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.annotate(line_eq,(100,50),xycoords="figure pixels",fontsize=15,color="red")
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3                  kristiansund  63.1115    7.7320     15.03        88
# 4             bikenibeu village   1.3673  173.1241     27.98        89
# 5                   yellowknife  62.4560 -114.3525     26.29        36
# 6                        albany  42.6001  -73.9662     27.24        80
# 9        hawaiian paradise park  19.5933 -154.9731     24.46        94
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3                75        1.54      NO  1688858855
# 4               100        3.09      KI  1688858856
# 5                40        5.66      CA  1688858856
# 6                94        0.87      US  1688858839
# 9               100        3.60      US  1688858858

# %%
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] <0]
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                grytviken -54.2811  -36.5092     -6.71        84          25
# 1                 waitangi -43.9535 -176.5597     12.12        80          50
# 2                   avarua -21.2078 -159.7750     27.03        78          75
# 7        port-aux-francais -49.3500   70.2167      1.02        78          98
# 8                adamstown -25.0660 -130.1015     22.05        77          76
#
#          Wind Speed Country        Date
# City_ID
# 0              5.34      GS  1688858853
# 1              1.79      NZ  1688858854
# 2              7.72      CK  1688858854
# 7              5.49      TF  1688858857
# 8              6.42      PN  1688858858

# %% [markdown]
# Temperature vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.4023601799628374

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.6493274190662389

# %% [markdown]
# Humidity vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.0035426787373660368

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
regression(x_values, y_values)
# Out:
# The r-value is: 2.875339403433156e-05

# %% [markdown]
# Cloudiness vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.001766654841721086

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.0007914497255359302

# %% [markdown]
# Wind Speed vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.028656545042708037

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.006467932741453281
