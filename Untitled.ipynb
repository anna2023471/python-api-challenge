# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units=metric&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
#         # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#     If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | eket
# Processing Record 2 of Set 1 | mirnyy
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | ventspils
# Processing Record 5 of Set 1 | lepsy
# Processing Record 6 of Set 1 | la passe
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | puerto natales
# Processing Record 9 of Set 1 | kiiminki
# Processing Record 10 of Set 1 | big bend
# Processing Record 11 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | grytviken
# Processing Record 14 of Set 1 | edinburgh of the seven seas
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | stanley
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | tolanaro
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | pacific grove
# Processing Record 22 of Set 1 | asau
# Processing Record 23 of Set 1 | sisimiut
# Processing Record 24 of Set 1 | vila franca do campo
# Processing Record 25 of Set 1 | uva
# Processing Record 26 of Set 1 | san luis de la loma
# Processing Record 27 of Set 1 | kapuskasing
# Processing Record 28 of Set 1 | ekibastuz
# Processing Record 29 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 30 of Set 1 | rio grande
# Processing Record 31 of Set 1 | broken hill
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | fortuna
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | palm springs
# Processing Record 36 of Set 1 | ouellah
# City not found. Skipping...
# Processing Record 37 of Set 1 | wailua homesteads
# Processing Record 38 of Set 1 | margaret river
# Processing Record 39 of Set 1 | hagere maryam
# Processing Record 40 of Set 1 | sorong
# Processing Record 41 of Set 1 | murakami
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | ust-nera
# Processing Record 44 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 45 of Set 1 | uturoa
# Processing Record 46 of Set 1 | jinchang
# Processing Record 47 of Set 1 | anadyr
# Processing Record 48 of Set 1 | chandia
# Processing Record 49 of Set 1 | forster
# Processing Record 50 of Set 1 | port lincoln
# Processing Record 0 of Set 2 | tura
# Processing Record 1 of Set 2 | sonsorol village
# City not found. Skipping...
# Processing Record 2 of Set 2 | koutiala
# Processing Record 3 of Set 2 | manokwari
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | adamstown
# Processing Record 7 of Set 2 | alta
# Processing Record 8 of Set 2 | fale old settlement
# Processing Record 9 of Set 2 | sitka
# Processing Record 10 of Set 2 | northam
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | hasaki
# Processing Record 13 of Set 2 | invercargill
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | blackmans bay
# Processing Record 16 of Set 2 | mount isa
# Processing Record 17 of Set 2 | bilibino
# Processing Record 18 of Set 2 | saynshand
# Processing Record 19 of Set 2 | haiku-pauwela
# Processing Record 20 of Set 2 | karratha
# Processing Record 21 of Set 2 | acapulco de juarez
# Processing Record 22 of Set 2 | keflavik
# Processing Record 23 of Set 2 | madaba
# Processing Record 24 of Set 2 | selfoss
# Processing Record 25 of Set 2 | puerto deseado
# Processing Record 26 of Set 2 | laguna
# Processing Record 27 of Set 2 | ciudad bolivar
# Processing Record 28 of Set 2 | warrnambool
# Processing Record 29 of Set 2 | ambalangoda
# Processing Record 30 of Set 2 | yangor
# City not found. Skipping...
# Processing Record 31 of Set 2 | yamada
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | hammerfest
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | nova sintra
# Processing Record 36 of Set 2 | talnakh
# Processing Record 37 of Set 2 | qarazhal
# Processing Record 38 of Set 2 | rasht
# Processing Record 39 of Set 2 | kilindoni
# Processing Record 40 of Set 2 | el bauga
# Processing Record 41 of Set 2 | bafq
# Processing Record 42 of Set 2 | kaa-khem
# Processing Record 43 of Set 2 | ebaye
# Processing Record 44 of Set 2 | swakopmund
# Processing Record 45 of Set 2 | arinos
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | badger
# Processing Record 48 of Set 2 | kiunga
# Processing Record 49 of Set 2 | lorengau
# Processing Record 0 of Set 3 | papao
# Processing Record 1 of Set 3 | sinabang
# Processing Record 2 of Set 3 | nueva gerona
# Processing Record 3 of Set 3 | bandon
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | braganca
# Processing Record 6 of Set 3 | papatowai
# Processing Record 7 of Set 3 | howrah
# Processing Record 8 of Set 3 | acarau
# Processing Record 9 of Set 3 | dalandzadgad
# Processing Record 10 of Set 3 | san antonio de pale
# Processing Record 11 of Set 3 | senador jose porfirio
# Processing Record 12 of Set 3 | magadan
# Processing Record 13 of Set 3 | coxen hole
# Processing Record 14 of Set 3 | minas de marcona
# Processing Record 15 of Set 3 | labrador city
# Processing Record 16 of Set 3 | santa ana
# Processing Record 17 of Set 3 | chibougamau
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | richards bay
# Processing Record 20 of Set 3 | qaqortoq
# Processing Record 21 of Set 3 | hovd
# Processing Record 22 of Set 3 | lata
# Processing Record 23 of Set 3 | afaahiti
# Processing Record 24 of Set 3 | khandyga
# Processing Record 25 of Set 3 | miyanoura
# City not found. Skipping...
# Processing Record 26 of Set 3 | whitehorse
# Processing Record 27 of Set 3 | hawaiian paradise park
# Processing Record 28 of Set 3 | al-`ula
# City not found. Skipping...
# Processing Record 29 of Set 3 | utrik
# Processing Record 30 of Set 3 | sambava
# Processing Record 31 of Set 3 | goz beida
# Processing Record 32 of Set 3 | antsiranana
# Processing Record 33 of Set 3 | nova vicosa
# Processing Record 34 of Set 3 | qamdo
# Processing Record 35 of Set 3 | mossel bay
# Processing Record 36 of Set 3 | quepos
# Processing Record 37 of Set 3 | karosta
# City not found. Skipping...
# Processing Record 38 of Set 3 | n'diareme limamoulaye
# City not found. Skipping...
# Processing Record 39 of Set 3 | cienega de flores
# Processing Record 40 of Set 3 | tazacorte
# Processing Record 41 of Set 3 | idri
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | kaka
# Processing Record 44 of Set 3 | iskateley
# Processing Record 45 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 46 of Set 3 | udachny
# Processing Record 47 of Set 3 | ta`u
# Processing Record 48 of Set 3 | borogontsy
# Processing Record 49 of Set 3 | hermanus
# Processing Record 0 of Set 4 | mitu
# Processing Record 1 of Set 4 | rongelap
# Processing Record 2 of Set 4 | ola
# Processing Record 3 of Set 4 | new plymouth
# Processing Record 4 of Set 4 | salekhard
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | fort st. john
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | olinda
# Processing Record 10 of Set 4 | sola
# Processing Record 11 of Set 4 | querqueville
# Processing Record 12 of Set 4 | sainte-marie
# Processing Record 13 of Set 4 | vilyuchinsk
# Processing Record 14 of Set 4 | aykhal
# Processing Record 15 of Set 4 | vilyuysk
# Processing Record 16 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 4 | candido de abreu
# Processing Record 18 of Set 4 | colonia
# Processing Record 19 of Set 4 | port saint john's
# Processing Record 20 of Set 4 | arauca
# Processing Record 21 of Set 4 | kerikeri
# Processing Record 22 of Set 4 | kirakira
# Processing Record 23 of Set 4 | upington
# Processing Record 24 of Set 4 | susuman
# Processing Record 25 of Set 4 | luganville
# Processing Record 26 of Set 4 | leer
# Processing Record 27 of Set 4 | bayanhongor
# Processing Record 28 of Set 4 | olonkinbyen
# Processing Record 29 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 30 of Set 4 | svetlyy
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | sodo
# Processing Record 33 of Set 4 | saipan
# Processing Record 34 of Set 4 | schoppenstedt
# Processing Record 35 of Set 4 | norderney
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | college
# Processing Record 38 of Set 4 | georgiyevka
# Processing Record 39 of Set 4 | fortaleza
# Processing Record 40 of Set 4 | tazovsky
# Processing Record 41 of Set 4 | aq qayeh
# City not found. Skipping...
# Processing Record 42 of Set 4 | berezovyy
# Processing Record 43 of Set 4 | norton shores
# Processing Record 44 of Set 4 | port mathurin
# Processing Record 45 of Set 4 | huarmey
# Processing Record 46 of Set 4 | avarua
# Processing Record 47 of Set 4 | port alfred
# Processing Record 48 of Set 4 | nova xavantina
# Processing Record 49 of Set 4 | ust'-ordynskiy
# Processing Record 0 of Set 5 | new norfolk
# Processing Record 1 of Set 5 | lycksele
# Processing Record 2 of Set 5 | klaksvik
# Processing Record 3 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 4 of Set 5 | laojunmiao
# Processing Record 5 of Set 5 | prado
# Processing Record 6 of Set 5 | myitkyina
# Processing Record 7 of Set 5 | slave lake
# Processing Record 8 of Set 5 | margate
# Processing Record 9 of Set 5 | usogorsk
# Processing Record 10 of Set 5 | inyati
# Processing Record 11 of Set 5 | conde
# Processing Record 12 of Set 5 | flying fish cove
# Processing Record 13 of Set 5 | kourou
# Processing Record 14 of Set 5 | merikanjaka
# City not found. Skipping...
# Processing Record 15 of Set 5 | fisterra
# Processing Record 16 of Set 5 | vorgashor
# Processing Record 17 of Set 5 | chernyshevskiy
# Processing Record 18 of Set 5 | chonchi
# Processing Record 19 of Set 5 | tabou
# Processing Record 20 of Set 5 | vernon
# Processing Record 21 of Set 5 | suoyarvi
# Processing Record 22 of Set 5 | kingston
# Processing Record 23 of Set 5 | ulsteinvik
# Processing Record 24 of Set 5 | vorkuta
# Processing Record 25 of Set 5 | alo
# Processing Record 26 of Set 5 | montepuez
# Processing Record 27 of Set 5 | paracuru
# Processing Record 28 of Set 5 | port douglas
# Processing Record 29 of Set 5 | kasane
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | urangan
# Processing Record 32 of Set 5 | aasiaat
# Processing Record 33 of Set 5 | yeosu
# Processing Record 34 of Set 5 | nar'yan-mar
# Processing Record 35 of Set 5 | wynyard
# Processing Record 36 of Set 5 | ellsworth
# Processing Record 37 of Set 5 | bantay
# Processing Record 38 of Set 5 | uliastay
# Processing Record 39 of Set 5 | constantia
# Processing Record 40 of Set 5 | bandar lampung
# Processing Record 41 of Set 5 | ostersund
# Processing Record 42 of Set 5 | carnarvon
# Processing Record 43 of Set 5 | nemuro
# Processing Record 44 of Set 5 | dudinka
# Processing Record 45 of Set 5 | zapadnaya dvina
# Processing Record 46 of Set 5 | cootamundra
# Processing Record 47 of Set 5 | west island
# Processing Record 48 of Set 5 | antofagasta
# Processing Record 49 of Set 5 | cabanas
# Processing Record 0 of Set 6 | la ronge
# Processing Record 1 of Set 6 | lembar
# City not found. Skipping...
# Processing Record 2 of Set 6 | tobruk
# Processing Record 3 of Set 6 | feicheng
# Processing Record 4 of Set 6 | vimperk
# Processing Record 5 of Set 6 | nampula
# Processing Record 6 of Set 6 | egilsstadir
# Processing Record 7 of Set 6 | enewetak
# Processing Record 8 of Set 6 | isafjordur
# Processing Record 9 of Set 6 | forde
# Processing Record 10 of Set 6 | markovo
# Processing Record 11 of Set 6 | nangong
# Processing Record 12 of Set 6 | rundu
# Processing Record 13 of Set 6 | smithers
# Processing Record 14 of Set 6 | hamilton
# Processing Record 15 of Set 6 | aleg
# Processing Record 16 of Set 6 | atafu village
# Processing Record 17 of Set 6 | padang
# Processing Record 18 of Set 6 | st. john's
# Processing Record 19 of Set 6 | san patricio
# Processing Record 20 of Set 6 | ascension
# Processing Record 21 of Set 6 | carauari
# Processing Record 22 of Set 6 | odate
# Processing Record 23 of Set 6 | naze
# Processing Record 24 of Set 6 | tamanrasset
# Processing Record 25 of Set 6 | micheweni
# Processing Record 26 of Set 6 | dapa
# Processing Record 27 of Set 6 | leshan
# Processing Record 28 of Set 6 | grand falls-windsor
# Processing Record 29 of Set 6 | mayna
# Processing Record 30 of Set 6 | al bayda'
# Processing Record 31 of Set 6 | remire-montjoly
# Processing Record 32 of Set 6 | lebu
# Processing Record 33 of Set 6 | arauco
# Processing Record 34 of Set 6 | ulanhot
# Processing Record 35 of Set 6 | lodja
# Processing Record 36 of Set 6 | aras-asan
# Processing Record 37 of Set 6 | huanren
# Processing Record 38 of Set 6 | yuzhno-kurilsk
# Processing Record 39 of Set 6 | ouadda
# Processing Record 40 of Set 6 | butembo
# Processing Record 41 of Set 6 | victoria de durango
# Processing Record 42 of Set 6 | tomatlan
# Processing Record 43 of Set 6 | quellon
# Processing Record 44 of Set 6 | beyneu
# Processing Record 45 of Set 6 | dolbeau-mistassini
# Processing Record 46 of Set 6 | inhambane
# Processing Record 47 of Set 6 | gamba
# Processing Record 48 of Set 6 | porto novo
# Processing Record 49 of Set 6 | tindouf
# Processing Record 0 of Set 7 | kailua-kona
# Processing Record 1 of Set 7 | vadso
# Processing Record 2 of Set 7 | olyokminsk
# Processing Record 3 of Set 7 | san nicolas
# Processing Record 4 of Set 7 | garko
# Processing Record 5 of Set 7 | danane
# Processing Record 6 of Set 7 | guerrero negro
# Processing Record 7 of Set 7 | ilulissat
# Processing Record 8 of Set 7 | ambovombe
# Processing Record 9 of Set 7 | topi
# Processing Record 10 of Set 7 | puerto baquerizo moreno
# Processing Record 11 of Set 7 | nantucket
# Processing Record 12 of Set 7 | chicoana
# Processing Record 13 of Set 7 | dalmatovo
# Processing Record 14 of Set 7 | ain sefra
# Processing Record 15 of Set 7 | shevchenkove
# Processing Record 16 of Set 7 | yaren
# Processing Record 17 of Set 7 | djenne
# Processing Record 18 of Set 7 | manta
# Processing Record 19 of Set 7 | balpyk bi
# Processing Record 20 of Set 7 | illizi
# Processing Record 21 of Set 7 | ketchikan
# Processing Record 22 of Set 7 | labytnangi
# Processing Record 23 of Set 7 | kutum
# Processing Record 24 of Set 7 | queensbury
# Processing Record 25 of Set 7 | okhotsk
# Processing Record 26 of Set 7 | el colomo
# Processing Record 27 of Set 7 | paimpol
# Processing Record 28 of Set 7 | akureyri
# Processing Record 29 of Set 7 | bodaybo
# Processing Record 30 of Set 7 | shamva
# Processing Record 31 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 32 of Set 7 | gazojak
# Processing Record 33 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 34 of Set 7 | bonny
# Processing Record 35 of Set 7 | horta
# Processing Record 36 of Set 7 | kavaratti
# Processing Record 37 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 38 of Set 7 | jincheng
# Processing Record 39 of Set 7 | campoverde
# Processing Record 40 of Set 7 | merizo village
# Processing Record 41 of Set 7 | ixtapa
# Processing Record 42 of Set 7 | sumbawa besar
# Processing Record 43 of Set 7 | tadine
# Processing Record 44 of Set 7 | gulf shores
# Processing Record 45 of Set 7 | vredendal
# Processing Record 46 of Set 7 | constitucion
# Processing Record 47 of Set 7 | mata-utu
# Processing Record 48 of Set 7 | kerch
# Processing Record 49 of Set 7 | machilipatnam
# Processing Record 0 of Set 8 | midvagur
# Processing Record 1 of Set 8 | san pedro pochutla
# Processing Record 2 of Set 8 | cam ranh
# Processing Record 3 of Set 8 | sakakah
# Processing Record 4 of Set 8 | dhuusamarreeb
# Processing Record 5 of Set 8 | pariaman
# Processing Record 6 of Set 8 | cheremushki
# Processing Record 7 of Set 8 | notodden
# Processing Record 8 of Set 8 | al kharijah
# Processing Record 9 of Set 8 | totskoye
# Processing Record 10 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 11 of Set 8 | newman
# Processing Record 12 of Set 8 | ad dabbah
# Processing Record 13 of Set 8 | guachochi
# City not found. Skipping...
# Processing Record 14 of Set 8 | reggane
# Processing Record 15 of Set 8 | belyy yar
# Processing Record 16 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 17 of Set 8 | dublyany
# Processing Record 18 of Set 8 | capo d'orlando
# Processing Record 19 of Set 8 | mbanza kongo
# Processing Record 20 of Set 8 | kramators'k
# Processing Record 21 of Set 8 | filiatra
# Processing Record 22 of Set 8 | huadian
# Processing Record 23 of Set 8 | tuy hoa
# Processing Record 24 of Set 8 | talodi
# Processing Record 25 of Set 8 | hpa-an
# Processing Record 26 of Set 8 | barro alto
# Processing Record 27 of Set 8 | worland
# Processing Record 28 of Set 8 | kuqa
# Processing Record 29 of Set 8 | vanimo
# Processing Record 30 of Set 8 | le port
# Processing Record 31 of Set 8 | la mira
# Processing Record 32 of Set 8 | madanapalle
# Processing Record 33 of Set 8 | mombetsu
# Processing Record 34 of Set 8 | kidal
# Processing Record 35 of Set 8 | geraldton
# Processing Record 36 of Set 8 | la alianza
# Processing Record 37 of Set 8 | kyakhta
# Processing Record 38 of Set 8 | jalai nur
# Processing Record 39 of Set 8 | primero de mayo
# Processing Record 40 of Set 8 | revda
# Processing Record 41 of Set 8 | alice springs
# Processing Record 42 of Set 8 | shingu
# Processing Record 43 of Set 8 | kwakoa
# Processing Record 44 of Set 8 | lethem
# Processing Record 45 of Set 8 | murun-kuren
# Processing Record 46 of Set 8 | rocky point
# Processing Record 47 of Set 8 | sandnessjoen
# Processing Record 48 of Set 8 | cooper's town
# Processing Record 49 of Set 8 | pelabuhan klang
# Processing Record 0 of Set 9 | stettler
# Processing Record 1 of Set 9 | ballina
# Processing Record 2 of Set 9 | leeton
# Processing Record 3 of Set 9 | waurn ponds
# Processing Record 4 of Set 9 | beni
# Processing Record 5 of Set 9 | robore
# Processing Record 6 of Set 9 | weno
# Processing Record 7 of Set 9 | mallawi
# Processing Record 8 of Set 9 | basco
# Processing Record 9 of Set 9 | tommot
# Processing Record 10 of Set 9 | tosontsengel
# Processing Record 11 of Set 9 | levuka
# Processing Record 12 of Set 9 | lubango
# Processing Record 13 of Set 9 | nizhnevartovsk
# Processing Record 14 of Set 9 | coquimbo
# Processing Record 15 of Set 9 | naantali
# Processing Record 16 of Set 9 | carutapera
# Processing Record 17 of Set 9 | turochak
# Processing Record 18 of Set 9 | veshenskaya
# Processing Record 19 of Set 9 | chegdomyn
# Processing Record 20 of Set 9 | monte carmelo
# Processing Record 21 of Set 9 | retreat
# Processing Record 22 of Set 9 | luderitz
# Processing Record 23 of Set 9 | madimba
# Processing Record 24 of Set 9 | sishilichengzi
# City not found. Skipping...
# Processing Record 25 of Set 9 | sanctuary point
# Processing Record 26 of Set 9 | lihue
# Processing Record 27 of Set 9 | sheridan
# Processing Record 28 of Set 9 | cidreira
# Processing Record 29 of Set 9 | aviano-castello
# City not found. Skipping...
# Processing Record 30 of Set 9 | laurentides
# Processing Record 31 of Set 9 | harrisonville
# Processing Record 32 of Set 9 | jinka
# Processing Record 33 of Set 9 | firuzabad
# Processing Record 34 of Set 9 | muli
# Processing Record 35 of Set 9 | palikir - national government center
# Processing Record 36 of Set 9 | palmer
# Processing Record 37 of Set 9 | kuala terengganu
# Processing Record 38 of Set 9 | masterton
# Processing Record 39 of Set 9 | saacow
# Processing Record 40 of Set 9 | toga village
# City not found. Skipping...
# Processing Record 41 of Set 9 | mega
# Processing Record 42 of Set 9 | punta del este
# Processing Record 43 of Set 9 | stolac
# Processing Record 44 of Set 9 | sierra grande
# Processing Record 45 of Set 9 | brisas de zicatela
# Processing Record 46 of Set 9 | santana
# Processing Record 47 of Set 9 | polyarnyy
# Processing Record 48 of Set 9 | podporozh'ye
# Processing Record 49 of Set 9 | luxembourg
# Processing Record 0 of Set 10 | east london
# Processing Record 1 of Set 10 | qalat
# Processing Record 2 of Set 10 | poltava
# Processing Record 3 of Set 10 | mtwara
# Processing Record 4 of Set 10 | tromso
# Processing Record 5 of Set 10 | puerto lempira
# Processing Record 6 of Set 10 | caleta de carquin
# Processing Record 7 of Set 10 | piti village
# Processing Record 8 of Set 10 | hilo
# Processing Record 9 of Set 10 | westport
# Processing Record 10 of Set 10 | kiambu
# Processing Record 11 of Set 10 | kabompo
# Processing Record 12 of Set 10 | qarqin
# Processing Record 13 of Set 10 | ndioum
# Processing Record 14 of Set 10 | tarfaya
# Processing Record 15 of Set 10 | kananga
# Processing Record 16 of Set 10 | blessington
# Processing Record 17 of Set 10 | tvoroyri
# Processing Record 18 of Set 10 | walvis bay
# Processing Record 19 of Set 10 | kittila
# Processing Record 20 of Set 10 | choibalsan
# Processing Record 21 of Set 10 | chui
# Processing Record 22 of Set 10 | grand-lahou
# Processing Record 23 of Set 10 | kertih
# Processing Record 24 of Set 10 | mahalapye
# Processing Record 25 of Set 10 | les cayes
# Processing Record 26 of Set 10 | taoudenni
# Processing Record 27 of Set 10 | mermoz boabab
# Processing Record 28 of Set 10 | manistee
# Processing Record 29 of Set 10 | priladozhskiy
# Processing Record 30 of Set 10 | pocone
# Processing Record 31 of Set 10 | kargil
# Processing Record 32 of Set 10 | leninogorsk
# Processing Record 33 of Set 10 | garissa
# Processing Record 34 of Set 10 | usinsk
# Processing Record 35 of Set 10 | tangalle
# Processing Record 36 of Set 10 | topeka
# Processing Record 37 of Set 10 | waingapu
# Processing Record 38 of Set 10 | callao
# Processing Record 39 of Set 10 | savalou
# Processing Record 40 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 10 | ulladulla
# Processing Record 42 of Set 10 | roma
# Processing Record 43 of Set 10 | fort bragg
# Processing Record 44 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 45 of Set 10 | windermere
# Processing Record 46 of Set 10 | crane
# Processing Record 47 of Set 10 | bakanas
# Processing Record 48 of Set 10 | nagqu
# Processing Record 49 of Set 10 | castillos
# Processing Record 0 of Set 11 | srikakulam
# Processing Record 1 of Set 11 | tralee
# Processing Record 2 of Set 11 | ninotsminda
# Processing Record 3 of Set 11 | goaso
# City not found. Skipping...
# Processing Record 4 of Set 11 | merritt island
# Processing Record 5 of Set 11 | nuuk
# Processing Record 6 of Set 11 | harwich
# Processing Record 7 of Set 11 | taltal
# Processing Record 8 of Set 11 | salinopolis
# Processing Record 9 of Set 11 | trinidad
# Processing Record 10 of Set 11 | kyelang
# Processing Record 11 of Set 11 | souillac
# Processing Record 12 of Set 11 | villa mercedes
# Processing Record 13 of Set 11 | ndele
# Processing Record 14 of Set 11 | gandajika
# Processing Record 15 of Set 11 | belozersk
# Processing Record 16 of Set 11 | benguela
# Processing Record 17 of Set 11 | mlangali
# Processing Record 18 of Set 11 | dawesville
# Processing Record 19 of Set 11 | sainte-anne-des-monts
# Processing Record 20 of Set 11 | kununurra
# Processing Record 21 of Set 11 | vilhena
# Processing Record 22 of Set 11 | kisangani
# Processing Record 23 of Set 11 | mpika
# Processing Record 24 of Set 11 | klyuchi
# Processing Record 25 of Set 11 | valparaiso
# Processing Record 26 of Set 11 | mwene-ditu
# Processing Record 27 of Set 11 | grafton
# Processing Record 28 of Set 11 | thunder bay
# Processing Record 29 of Set 11 | guatrache
# Processing Record 30 of Set 11 | serhiyivka
# Processing Record 31 of Set 11 | dongola
# Processing Record 32 of Set 11 | sungai raya
# Processing Record 33 of Set 11 | pizarro
# Processing Record 34 of Set 11 | al qubbah
# Processing Record 35 of Set 11 | koryazhma
# Processing Record 36 of Set 11 | arkhangel'sk
# Processing Record 37 of Set 11 | ibiza
# Processing Record 38 of Set 11 | sokolka
# Processing Record 39 of Set 11 | pahlgam
# Processing Record 40 of Set 11 | zemio
# Processing Record 41 of Set 11 | hilton head island
# Processing Record 42 of Set 11 | 'alaqahdari dishu
# Processing Record 43 of Set 11 | khamis mushait
# Processing Record 44 of Set 11 | tanjung selor
# City not found. Skipping...
# Processing Record 45 of Set 11 | dryden
# Processing Record 46 of Set 11 | misratah
# Processing Record 47 of Set 11 | muisne
# Processing Record 48 of Set 11 | volpiano
# Processing Record 49 of Set 11 | pajapan
# Processing Record 0 of Set 12 | lisala
# Processing Record 1 of Set 12 | kaiapoi
# Processing Record 2 of Set 12 | mejit
# Processing Record 3 of Set 12 | lavrio
# Processing Record 4 of Set 12 | dakhla
# Processing Record 5 of Set 12 | guadalajara
# Processing Record 6 of Set 12 | lazaro cardenas
# Processing Record 7 of Set 12 | soio
# Processing Record 8 of Set 12 | hithadhoo
# Processing Record 9 of Set 12 | galich
# Processing Record 10 of Set 12 | undurkhaan
# Processing Record 11 of Set 12 | touros
# Processing Record 12 of Set 12 | champerico
# Processing Record 13 of Set 12 | tual
# Processing Record 14 of Set 12 | yeghegnadzor
# Processing Record 15 of Set 12 | colonia nicolich
# Processing Record 16 of Set 12 | makarov
# Processing Record 17 of Set 12 | bowen
# Processing Record 18 of Set 12 | cromer
# Processing Record 19 of Set 12 | nabire
# Processing Record 20 of Set 12 | fort mcmurray
# Processing Record 21 of Set 12 | el calafate
# Processing Record 22 of Set 12 | aripuana
# Processing Record 23 of Set 12 | la'ie
# Processing Record 24 of Set 12 | sunland park
# Processing Record 25 of Set 12 | colares
# Processing Record 26 of Set 12 | evanston
# Processing Record 27 of Set 12 | ban dung
# Processing Record 28 of Set 12 | blackwater
# Processing Record 29 of Set 12 | pandan
# Processing Record 30 of Set 12 | tlamacazapa
# Processing Record 31 of Set 12 | bom jesus
# Processing Record 32 of Set 12 | batang
# Processing Record 33 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 34 of Set 12 | kruisfontein
# Processing Record 35 of Set 12 | queenstown
# Processing Record 36 of Set 12 | diffa
# Processing Record 37 of Set 12 | raduzhnyy
# Processing Record 38 of Set 12 | samana
# Processing Record 39 of Set 12 | bada
# Processing Record 40 of Set 12 | chust
# Processing Record 41 of Set 12 | al jawf
# Processing Record 42 of Set 12 | comayagua
# Processing Record 43 of Set 12 | mili
# Processing Record 44 of Set 12 | kawardha
# Processing Record 45 of Set 12 | veszprem
# Processing Record 46 of Set 12 | melekeok village
# Processing Record 47 of Set 12 | janow lubelski
# Processing Record 48 of Set 12 | krasnogorskoye
# Processing Record 49 of Set 12 | changji
# Processing Record 0 of Set 13 | severo-yeniseyskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        eket   4.6412    7.9209     23.43        93         100        1.06
# 1      mirnyy  62.5353  113.9611     25.98        33          34        0.51
# 2  bredasdorp -34.5322   20.0403      9.71        85          96        4.70
# 3   ventspils  57.3894   21.5606     17.96        88           0        3.60
# 4       lepsy  46.2350   78.9456     25.93        39          88        1.56
#
#   Country        Date
# 0      NG  1688879843
# 1      RU  1688879843
# 2      ZA  1688879844
# 3      LV  1688879844
# 4      KZ  1688879845

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              eket   4.6412    7.9209     23.43        93         100
# 1            mirnyy  62.5353  113.9611     25.98        33          34
# 2        bredasdorp -34.5322   20.0403      9.71        85          96
# 3         ventspils  57.3894   21.5606     17.96        88           0
# 4             lepsy  46.2350   78.9456     25.93        39          88
#
#          Wind Speed Country        Date
# City_ID
# 0              1.06      NG  1688879843
# 1              0.51      RU  1688879843
# 2              4.70      ZA  1688879844
# 3              3.60      LV  1688879844
# 4              1.56      KZ  1688879845

# %% [markdown]
# # Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude = city_data_df["Lat"]
temperature = city_data_df["Max Temp"]
plt.scatter(latitude, temperature, edgecolors="black")

# Incorporate the other graph properties
today = time.strftime("%Y-%m-%d")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Max Latitude vs Temperature ({today})")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude = city_data_df["Lat"]
humidity = city_data_df["Humidity"]
plt.scatter(latitude, humidity, edgecolors="black")

# Incorporate the other graph properties
today = time.strftime("%Y-%m-%d")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Max Latitude vs Humidity ({today})")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]
plt.scatter(latitude, cloudiness, edgecolors="black")

# Incorporate the other graph properties
today = time.strftime("%Y-%m-%d")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Max Latitude vs Cloudiness ({today})")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs Wind Speed

# %%
# Build the scatter plots for latitude vs. wind speed
latitude = city_data_df["Lat"]
wind_speed = city_data_df["Wind Speed"]
plt.scatter(latitude, wind_speed, edgecolors="black")


# Incorporate the other graph properties
today = time.strftime("%Y-%m-%d")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Max Latitude vs Wind Speed ({today})")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Define a function to create Linear Regression plots
def regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.annotate(line_eq,(100,50),xycoords="figure pixels",fontsize=15,color="red")
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             eket   4.6412    7.9209     23.43        93         100
# 1           mirnyy  62.5353  113.9611     25.98        33          34
# 3        ventspils  57.3894   21.5606     17.96        88           0
# 4            lepsy  46.2350   78.9456     25.93        39          88
# 5         la passe  45.5549   -0.8967     19.43        89           5
#
#          Wind Speed Country        Date
# City_ID
# 0              1.06      NG  1688879843
# 1              0.51      RU  1688879843
# 3              3.60      LV  1688879844
# 4              1.56      KZ  1688879845
# 5              3.03      FR  1688879846

# %%
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] <0]
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2               bredasdorp -34.5322  20.0403      9.71        85          96
# 7           puerto natales -51.7236 -72.4875     -4.21        89          10
# 9                 big bend -26.8167  31.9333     14.33        70           0
# 10       port-aux-francais -49.3500  70.2167      1.44        60          99
# 11               grytviken -54.2811 -36.5092     -5.93        84          63
#
#          Wind Speed Country        Date
# City_ID
# 2              4.70      ZA  1688879844
# 7              0.99      CL  1688879847
# 9              1.35      SZ  1688879848
# 10             7.77      TF  1688879850
# 11             5.38      GS  1688879850

# %% [markdown]
# # Temperature vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.3251433451630899

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.6110459511485056

# %% [markdown]
# Discussion about the linear relationship: There is a moderate correlation between latitude and temperature, with temperatures increasing towards the equator and decreasing towards the poles.

# %% [markdown]
# # Humidity vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.01732722848101143

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.0007500075209340025

# %% [markdown]
# Discussion about the linear relationship: There is a very weak correlation between latitude and humidity, with humidity increasing towards the equator and decreasing towards the poles.

# %% [markdown]
# # Cloudiness vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
regression(x_values, y_values)
plt.savefig("output_data/Fig8.png")
# Out:
# The r-value is: 0.004153076987268458

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.023579583177270463

# %% [markdown]
# Discussion about the linear relationship: There appears to be no overall correlation between latitude and cloudiness, as cloudiness increases towards the equator from the north pole, but decreases towards the equator from the south pole.

# %% [markdown]
# # Wind Speed vs. Latitude Linear Regression Plot

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.004672882951129505

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
regression(x_values, y_values)
# Out:
# The r-value is: 0.03223763134975565

# %% [markdown]
# Discussion about the linear relationship: There appears to be no correlation bwteen latitude and wind speed, as wind speed increases towards the equator from the north pole, but decreases towards the equator from the south pole.
